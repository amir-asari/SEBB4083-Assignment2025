# %% [markdown]
# <a href="https://colab.research.google.com/github/amir-asari/SEBB4083-Assignment2025/blob/main/SEBB4083_Mini_Project_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mini Project 2025 (Pain Facial Expression Detection)
#
# > Add blockquote
#
#
# ### Total marks: 15 Marks
#
# ### Group No.:
#
# ###Group Members:
# 1)....
#
# 2)....
#
# 3)....
#
# 4)....
#
# 5)....
#
# 6)....

# %% [markdown]
# ## Chapter 1: Introduction
# xxxxxxx
# xxxxxxx

# %% [markdown]
# ###1.1 Background of study and related works
#
# xxxxxxx

# %% [markdown]
# ###1.2 Objectives
#
# xxxxxxx

# %% [markdown]
# ## Chapter 2: Methodology and Results

# %% [markdown]
# Explain step by step together with code and results............

# %%
## (write your codes here)

# %% [markdown]
# ## Chapter 3: Discussion
#
# You may discuss the comparison of result from each cases. What happen when you are varying the desired parameter

# %% [markdown]
# ## Chapter 4: Conclusion
#
# xxxxxxx

# %% [markdown]
# ## References
# 1)xxxxxx
